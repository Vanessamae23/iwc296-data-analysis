# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import sympy as sp
from sympy import *

# %%
def sum(x):
    sum = 0
    for value in x:
        sum  += value
    return sum
    
v = [2,3,4,10,24]
sum(v)
# Out:
# 43
