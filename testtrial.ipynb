# %%
import math
time = input("Enter your time score : ")
if not time.isdigit():
    print("Not a digit number")
else:
    minutes, seconds = divmod(time)
    print(f"{minutes} minutes, {seconds} seconds..")
